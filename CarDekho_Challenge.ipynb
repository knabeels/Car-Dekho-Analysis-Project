# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Checking Missing Values or Null Values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
# Checking Different Statistical Algo

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
f_dataset = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
f_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
grouped_sell_present = pd.DataFrame(f_dataset.groupby(['Fuel_Type'])[['Selling_Price', 'Present_Price']].mean())

# %%
grouped_sell_present
# Out:
#            Selling_Price  Present_Price
# Fuel_Type
# CNG             3.100000       6.415000
# Diesel         10.278500      15.814500
# Petrol          3.264184       5.583556

# %%
grouped_sell_present.plot(kind='bar')
plt.show()

# %%
grouped_kms = pd.DataFrame(f_dataset.groupby(['Fuel_Type'])[['Kms_Driven']].mean())

# %%
grouped_kms
# Out:
#              Kms_Driven
# Fuel_Type
# CNG        42749.000000
# Diesel     50369.916667
# Petrol     33528.937238

# %%
grouped_kms.plot(kind='bar')
plt.show()

# %%
grouped_sell_present1 =  f_dataset.groupby(['Seller_Type'])[['Selling_Price', 'Present_Price']].sum()
grouped_sell_present1
# Out:
#              Selling_Price  Present_Price
# Seller_Type
# Dealer             1310.73        2122.83
# Individual           92.32         173.34

# %%
grouped_sell_present1.plot(kind='bar')
plt.show()

# %%
grouped_kms1 = pd.DataFrame(f_dataset.groupby(['Seller_Type'])[['Kms_Driven']].mean())
grouped_kms1
# Out:
#                Kms_Driven
# Seller_Type
# Dealer       39850.133333
# Individual   31606.915094

# %%
grouped_kms1.plot(kind='bar')
plt.show()

# %%
f_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
grouped_sell_present2 = pd.DataFrame(f_dataset.groupby(['Transmission'])[['Selling_Price', 'Present_Price']].mean())
grouped_sell_present2
# Out:
#               Selling_Price  Present_Price
# Transmission
# Automatic          9.420000      15.315500
# Manual             3.931992       6.450383

# %%
grouped_sell_present2.plot(kind = 'bar')
plt.show()

# %%
grouped_kms2 = pd.DataFrame(f_dataset.groupby(['Transmission'])[['Kms_Driven']].mean())
grouped_kms2
# Out:
#                 Kms_Driven
# Transmission
# Automatic     53062.975000
# Manual        34477.356322

# %%
grouped_kms2.plot(kind='barh')
plt.show()

# %%
grouped_sell_present3 = pd.DataFrame(f_dataset.groupby(['Year'])[['Selling_Price', 'Present_Price']].mean())
grouped_sell_present3
# Out:
#       Selling_Price  Present_Price
# Year
# 2003       1.300000       5.130000
# 2004       1.500000      12.350000
# 2005       2.487500       9.485000
# 2006       1.437500       9.057500
# 2007       0.160000       0.665000
# 2008       1.002857       4.759571
# 2009       2.816667      10.601667
# 2010       5.262667      14.330667
# 2011       2.375263       5.148053
# 2012       3.841304       7.984783
# 2013       3.540909       6.821121
# 2014       4.762105       7.837974
# 2015       5.927049       8.181967
# 2016       5.213200       6.550800
# 2017       6.209143       7.008571
# 2018       9.250000       9.830000

# %%
grouped_sell_present3.plot(kind='bar')
plt.show()

# %%
grouped_kms3 = pd.DataFrame(f_dataset.groupby(['Year'])[['Kms_Driven']].mean())
grouped_kms3
# Out:
#          Kms_Driven
# Year
# 2003   94500.000000
# 2004  135154.000000
# 2005  104294.000000
# 2006   87422.250000
# 2007   51000.000000
# 2008  112128.571429
# 2009   67820.500000
# 2010   60014.066667
# 2011   40327.368421
# 2012   43798.217391
# 2013   41534.333333
# 2014   38080.315789
# 2015   32109.196721
# 2016   18387.340000
# 2017   10419.800000
# 2018    2071.000000

# %%
grouped_kms3.plot(kind='barh')
plt.show()

# %%
f_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
f_dataset['Current_Year'] = 2023

# %%
f_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2023
# 1       Manual      0          2023
# 2       Manual      0          2023
# 3       Manual      0          2023
# 4       Manual      0          2023

# %%
f_dataset['No_Years'] = f_dataset['Current_Year'] - f_dataset['Year']

# %%
f_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  No_Years
# 0       Manual      0          2023         9
# 1       Manual      0          2023        10
# 2       Manual      0          2023         6
# 3       Manual      0          2023        12
# 4       Manual      0          2023         9

# %%
f_dataset.drop(columns = ['Year'], inplace = True)
f_dataset.drop(columns = ['Current_Year'], inplace = True)

# %%
f_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No_Years
# 0         Manual      0         9
# 1         Manual      0        10
# 2         Manual      0         6
# ...

# %%
f_dataset['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
f_dataset['Fuel_Type'] = LE.fit_transform(f_dataset['Fuel_Type'])
f_dataset['Seller_Type'] = LE.fit_transform(f_dataset['Seller_Type'])
f_dataset['Transmission'] = LE.fit_transform(f_dataset['Transmission'])

# %%
f_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          2            0
# 3             2.85           4.15        5200          2            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          2            0
# 298           3.35          11.00       87934          2            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          2            0
#
#      Transmission  Owner  No_Years
# 0               1      0         9
# 1               1      0        10
# ...

# %%
f_dataset['Fuel_Type'] = f_dataset['Fuel_Type'].astype('int')
f_dataset['Seller_Type'] = f_dataset['Seller_Type'].astype('int')
f_dataset['Transmission'] = f_dataset['Transmission'].astype('int')

# %%
f_dataset.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Selling_Price       1.000000       0.878983    0.029187  -0.509467
# Present_Price       0.878983       1.000000    0.203647  -0.440415
# Kms_Driven          0.029187       0.203647    1.000000  -0.166801
# Fuel_Type          -0.509467      -0.440415   -0.166801   1.000000
# Seller_Type        -0.550724      -0.512030   -0.101419   0.352415
# Transmission       -0.367128      -0.348715   -0.162510   0.080466
# Owner              -0.088344       0.008057    0.089216   0.055705
# No_Years           -0.236141       0.047584    0.524342   0.053643
#
#                Seller_Type  Transmission     Owner  No_Years
# Selling_Price    -0.550724     -0.367128 -0.088344 -0.236141
# Present_Price    -0.512030     -0.348715  0.008057  0.047584
# Kms_Driven       -0.101419     -0.162510  0.089216  0.524342
# Fuel_Type         0.352415      0.080466  0.055705  0.053643
# ...

# %%
f_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          2            0
# 3             2.85           4.15        5200          2            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          2            0
# 298           3.35          11.00       87934          2            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          2            0
#
#      Transmission  Owner  No_Years
# 0               1      0         9
# 1               1      0        10
# ...

# %%
f_dataset['Fuel_Type'].unique()
# Out:
# array([2, 1, 0])

# %%
f_dataset['Seller_Type'].unique()
# Out:
# array([0, 1])

# %%
f_dataset['Transmission'].unique()
# Out:
# array([1, 0])

# %%
x=f_dataset.iloc[:,1:]
y=f_dataset.iloc[:,0]

# %%
x
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            0             1      0
# 1             9.54       43000          1            0             1      0
# 2             9.85        6900          2            0             1      0
# 3             4.15        5200          2            0             1      0
# 4             6.87       42450          1            0             1      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          1            0             1      0
# 297           5.90       60000          2            0             1      0
# 298          11.00       87934          2            0             1      0
# 299          12.50        9000          1            0             1      0
# 300           5.90        5464          2            0             1      0
#
#      No_Years
# 0           9
# 1          10
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 246           6.79       35000          2            0             1      0
# 244           9.40       49000          1            0             1      0
# 28            3.95       44542          2            0             1      0
# 144           0.99       25000          2            1             1      0
# 80           14.89       23000          1            0             1      0
# ..             ...         ...        ...          ...           ...    ...
# 101           1.82        1400          2            1             1      0
# 290           6.40       19000          2            0             1      0
# 178           0.52       19000          2            1             0      0
# 267           9.40       19434          1            0             1      0
# 287           7.50       44000          2            0             0      0
#
#      No_Years
# 246        11
# 244        10
# ...

# %%
from sklearn import linear_model
Lasso_a = linear_model.Lasso()

# %%
Lasso_a.fit(x_train, y_train)
# Out:
# Lasso()

# %%
y_pred = Lasso_a.predict(x_test)
print(y_pred)
# Out:
# [ 2.40877005  2.39582861  3.17875598  4.4749891   1.84314063  3.96829028
#   8.46813412  5.15339084  6.56754226  6.97805393  4.29842555 -2.23735858
#  -0.06923952  8.59688128  6.17242686  1.48296306  5.30994109  1.11859767
#   8.10873787  5.59037527  2.54582832  2.41072343  2.34411855  4.67132323
#   8.16864148  8.64391305  5.03101733  8.3456638   6.64840764  0.20946322
#   2.39070021  6.12197018  1.77612785 16.60697583  5.6780872   6.97805393
#   8.52075813  0.35482192  3.10192779  4.96810132  5.42739031  0.11965366
#   5.18374986  8.47809635  2.85948123  4.36124729  4.71876953  0.8702934
#   2.3133971   4.72261472  4.99692456  6.032454    8.43439927  6.22381728
#   0.87539141  4.44457479  2.89189555  7.70628989  2.02241362  9.75114011
#   2.84696784]

# %%
from sklearn.metrics import r2_score
r2_score(y_pred, y_test)
# Out:
# 0.7219243189622304

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_pred, y_test)
# Out:
# 1.186505769870435

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred, y_test)
# Out:
# 2.691496633730511

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
import pickle
# Save model
with open("model.pkl", "wb") as f:
    pickle.dump(Lasso_a, f)

# %%
# Load model
with open("model.pkl", "rb") as f:
    pickled_model = pickle.load(f)
pickled_model.predict(x_test)
# Out:
# array([ 2.40877005,  2.39582861,  3.17875598,  4.4749891 ,  1.84314063,
#         3.96829028,  8.46813412,  5.15339084,  6.56754226,  6.97805393,
#         4.29842555, -2.23735858, -0.06923952,  8.59688128,  6.17242686,
#         1.48296306,  5.30994109,  1.11859767,  8.10873787,  5.59037527,
#         2.54582832,  2.41072343,  2.34411855,  4.67132323,  8.16864148,
#         8.64391305,  5.03101733,  8.3456638 ,  6.64840764,  0.20946322,
#         2.39070021,  6.12197018,  1.77612785, 16.60697583,  5.6780872 ,
#         6.97805393,  8.52075813,  0.35482192,  3.10192779,  4.96810132,
#         5.42739031,  0.11965366,  5.18374986,  8.47809635,  2.85948123,
#         4.36124729,  4.71876953,  0.8702934 ,  2.3133971 ,  4.72261472,
#         4.99692456,  6.032454  ,  8.43439927,  6.22381728,  0.87539141,
#         4.44457479,  2.89189555,  7.70628989,  2.02241362,  9.75114011,
#         2.84696784])

# %%
pickled_model.predict([[5.59,	27000,	2,	2,	2,	0,	9]])
# Out:
# /Users/knabeels/Developer/Projects/Car-Dekho-Analysis-Project/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# array([3.79584987])
